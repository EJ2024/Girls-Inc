# %%
import pandas as pd

# %%
SSBOS_19_KW = pd.read_csv(r"C:\Users\parml\Desktop\GI\2019 SSBOS TN Valley.csv")

# %%
SSBOS_19_KW.columns
# Out:
# Index(['ResponseDate', 'IDOS', 'TenureMonths', 'TenureBuckets', 'Affiliate',
#        'DOB', 'SurveyAge', 'Grade', 'Gender', 'Race',
#        ...
#        'EE_PROGIRL_FUTURE', 'EE_INTENT_TIME_R', 'EE_INTENT_BUILD_R',
#        'EE_INTENT_DISORG_R', 'EE_INTENT_IDEAS', 'EE_INTER_DECIDE',
#        'EE_INTER_TGTHR', 'EE_INTER_THINGS', 'AgeGroup', 'PrimaryLast'],
#       dtype='object', length=165)

# %%
pd.set_option('display.max.columns', 170)
pd.set_option('display.max.rows', 200)
SSBOS_19_KW.head()
# Out:
#   ResponseDate      IDOS TenureMonths TenureBuckets                Affiliate  \
# 0     4-Feb-19  1-Jan-16           37             5  Girls Inc. of TN Valley
# 1     6-Feb-19  1-Jun-14           56             6  Girls Inc. of TN Valley
# 2    13-May-19  1-Jun-14           59             6  Girls Inc. of TN Valley
# 3    18-Mar-19  1-Jun-14           57             6  Girls Inc. of TN Valley
# 4    14-May-19  1-Jun-14           59             6  Girls Inc. of TN Valley
#
#          DOB SurveyAge Grade Gender  \
# 0   1-May-08        10     4      1
# 1  23-Jul-07        11     4      1
# 2   3-Sep-08        10     4      1
# 3  12-Dec-07        11     6      1
# 4  28-May-07        11     7      1
#
#                                           Race Race_GIStandards  \
# 0                                        White                7
# 1                                        White                7
# 2                                        White                7
# ...

# %%
Race_Income = SSBOS_19_KW.groupby(['Race','Income_GIStandards']).size()
#Count on Race by income
# Out:
# Race                                          Income_GIStandards
# -                                             2                      1
#                                               4                      1
# Asian American (Canadian) / Pacific Islander  4                      1
# Black / African American (Canadian)           #NULL!                 5
#                                               1                     13
#                                               2                      9
#                                               3                      7
#                                               4                      7
#                                               5                      2
#                                               99                     1
# Latina/Hispanic/Latin American                #NULL!                 2
#                                               1                      1
# ...

# %%
Race_Income_df=pd.DataFrame(SSBOS_19_KW.groupby(['Race','Income_GIStandards']).size())
Race_Income_df

#Create df

#RAA = SSBOS_19_KW2['RAA'].value_counts()  
#RAA_df = pd.DataFrame(SSBOS_19_KW2['RAA'].value_counts()) 
#RAA_df
# Out:
#                                                                   0
# Race                                         Income_GIStandards
# -                                            2                    1
#                                              4                    1
# Asian American (Canadian) / Pacific Islander 4                    1
# Black / African American (Canadian)          #NULL!               5
#                                              1                   13
#                                              2                    9
#                                              3                    7
#                                              4                    7
#                                              5                    2
#                                              99                   1
# Latina/Hispanic/Latin American               #NULL!               2
#                                              1                    1
# ...

# %%
Race_Income_cat = Race_Income_df.rename(index={'-':"Unknown/Unavailable"})
Race_Income_cat
# Out:
#                                                                   0
# Race                                         Income_GIStandards
# Unknown/Unavailable                          2                    1
#                                              4                    1
# Asian American (Canadian) / Pacific Islander 4                    1
# Black / African American (Canadian)          #NULL!               5
#                                              1                   13
#                                              2                    9
#                                              3                    7
#                                              4                    7
#                                              5                    2
#                                              99                   1
# Latina/Hispanic/Latin American               #NULL!               2
#                                              1                    1
# ...

# %%
Race_Income_cat_index = Race_Income_cat.reset_index()
Race_Income_cat_index
# Out:
#                                             Race Income_GIStandards   0
# 0                            Unknown/Unavailable                  2   1
# 1                            Unknown/Unavailable                  4   1
# 2   Asian American (Canadian) / Pacific Islander                  4   1
# 3            Black / African American (Canadian)             #NULL!   5
# 4            Black / African American (Canadian)                  1  13
# 5            Black / African American (Canadian)                  2   9
# 6            Black / African American (Canadian)                  3   7
# 7            Black / African American (Canadian)                  4   7
# 8            Black / African American (Canadian)                  5   2
# 9            Black / African American (Canadian)                 99   1
# 10                Latina/Hispanic/Latin American             #NULL!   2
# 11                Latina/Hispanic/Latin American                  1   1
# ...

# %%
Race_Income_cat_index.rename(columns = {0:'Count'}, inplace = True)
Race_Income_cat_index
#reset index/rename columns
# Out:
#                                             Race Income_GIStandards  Count
# 0                            Unknown/Unavailable                  2      1
# 1                            Unknown/Unavailable                  4      1
# 2   Asian American (Canadian) / Pacific Islander                  4      1
# 3            Black / African American (Canadian)             #NULL!      5
# 4            Black / African American (Canadian)                  1     13
# 5            Black / African American (Canadian)                  2      9
# 6            Black / African American (Canadian)                  3      7
# 7            Black / African American (Canadian)                  4      7
# 8            Black / African American (Canadian)                  5      2
# 9            Black / African American (Canadian)                 99      1
# 10                Latina/Hispanic/Latin American             #NULL!      2
# ...

# %%
Race_Income_cat_index.columns = Race_Income_cat_index.columns.astype("str")
Race_Income_cat_index.columns
#call column names for plotting
# Out:
# Index(['Race', 'Income_GIStandards', 'Count'], dtype='object')

# %%
Race_Income_cat_index.columns = Race_Income_cat_index.columns.str.replace(' ', '')
Race_Income_cat_index.columns 
#remove space for proper name
# Out:
# Index(['Race', 'Income_GIStandards', 'Count'], dtype='object')

# %%
Race_Income_cat_index.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Race                32 non-null     object
#  1   Income_GIStandards  32 non-null     object
#  2   Count               32 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 900.0+ bytes

# %%
#various plot types

# %%
sns.barplot(Race_Income_cat_index, x = 'Race', y = 'Count')
plt.plot()
# Out:
# []

# %%
sns.barplot(Race_Income_cat_index, x = 'Income_GIStandards', y = 'Count')
plt.plot()
# Out:
# []

# %%
sns.pairplot(Race_Income_cat_index, hue = 'Race')
# Out:
# C:\Users\parml\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.stripplot(x= 'Income_GIStandards', y = 'Count', data = Race_Income_cat_index, hue = 'Race')
# Out:
# <Axes: xlabel='Income_GIStandards', ylabel='Count'>

# %%
sns.stripplot(x= 'Race', y = 'Count', data = Race_Income_cat_index, hue = 'Income_GIStandards')
# Out:
# <Axes: xlabel='Race', ylabel='Count'>

# %%
Race_Income_cat_count = Race_Income_cat_index.groupby(['Race','Income_GIStandards'])['Count'].sum() 
Race_Income_cat_count
# Out:
# Race                                          Income_GIStandards
# Asian American (Canadian) / Pacific Islander  4                      1
# Black / African American (Canadian)           #NULL!                 5
#                                               1                     13
#                                               2                      9
#                                               3                      7
#                                               4                      7
#                                               5                      2
#                                               99                     1
# Latina/Hispanic/Latin American                #NULL!                 2
#                                               1                      1
#                                               2                      3
#                                               3                      1
# ...

# %%
Race_Income_Final_df = pd.DataFrame(Race_Income_cat_count) 
Race_Income_Final_df
# Out:
#                                                                  Count
# Race                                         Income_GIStandards
# Asian American (Canadian) / Pacific Islander 4                       1
# Black / African American (Canadian)          #NULL!                  5
#                                              1                      13
#                                              2                       9
#                                              3                       7
#                                              4                       7
#                                              5                       2
#                                              99                      1
# Latina/Hispanic/Latin American               #NULL!                  2
#                                              1                       1
#                                              2                       3
# ...

# %%
#reset index

# %%
Race_Income_Final_df.reset_index()
# Out:
#                                             Race Income_GIStandards  Count
# 0   Asian American (Canadian) / Pacific Islander                  4      1
# 1            Black / African American (Canadian)             #NULL!      5
# 2            Black / African American (Canadian)                  1     13
# 3            Black / African American (Canadian)                  2      9
# 4            Black / African American (Canadian)                  3      7
# 5            Black / African American (Canadian)                  4      7
# 6            Black / African American (Canadian)                  5      2
# 7            Black / African American (Canadian)                 99      1
# 8                 Latina/Hispanic/Latin American             #NULL!      2
# 9                 Latina/Hispanic/Latin American                  1      1
# 10                Latina/Hispanic/Latin American                  2      3
# ...

# %%
list(Race_Income_Final_df.columns.values) #calling columns name for plotting
# Out:
# ['Count']

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
Race_Income_Final_df.rename({'Income_GIStandards':'Income'}, inplace = True)
Race_Income_Final_df
# Out:
#                                                                  Count
# Race                                         Income_GIStandards
# Asian American (Canadian) / Pacific Islander 4                       1
# Black / African American (Canadian)          #NULL!                  5
#                                              1                      13
#                                              2                       9
#                                              3                       7
#                                              4                       7
#                                              5                       2
#                                              99                      1
# Latina/Hispanic/Latin American               #NULL!                  2
#                                              1                       1
#                                              2                       3
# ...

# %%
SSBOS_19_KW['WhichSurvey'].value_counts() #count survey types administered
# Out:
# WhichSurvey
# 1    168
# 2     10
# Name: count, dtype: int64

# %%
SSBOS_19_KW.drop(['ResponseDate', 'SurveyAge', 'Grade', 'DOB', 'Race', 'HouseholdType_GIStandards', 'Income_GIStandards', 'Race_GIStandards', 'Language_GIStandards', 'Gender', 'IDOS', 'TenureMonths', 'TenureBuckets', 'Affiliate', 'ASSENT', 'HONEST', 'AGECONFIRM', 'ReclassifiedTeen', 'ReclassifiedYouth', 'AgeIssueResolved', 'WhichSurvey'], axis = 1)
# Out:
#     HEALTH_BRKFST HEALTH_FRUIT HEALTH_VEG HEALTH_SODA HEALTH_FASTFOOD  \
# 0               1            2          1           1               1
# 1               1            3          2           0               1
# 2               1       #NULL!     #NULL!      #NULL!          #NULL!
# 3               1            2          2           1               0
# 4          #NULL!       #NULL!     #NULL!      #NULL!          #NULL!
# ..            ...          ...        ...         ...             ...
# 173             1            3          0           0               0
# 174             1            3          3           1               1
# 175             1            3          1           2               0
# 176             1            5          2           1               1
# 177             0            0          0           0               0
#
#     HEALTH_MILK HEALTH_VEND HEALTH_EXERCISE HEALTH_TEAM BODYIMAGE_PRTY_R  ...  \
# ...

# %%
SSBOS_19_KW2=SSBOS_19_KW.drop(['ResponseDate', 'SurveyAge', 'Grade', 'DOB', 'Race', 'HouseholdType_GIStandards', 'Income_GIStandards', 'Race_GIStandards', 'Language_GIStandards', 'Gender', 'IDOS', 'TenureMonths', 'TenureBuckets', 'Affiliate', 'ASSENT', 'HONEST', 'AGECONFIRM', 'ReclassifiedTeen', 'ReclassifiedYouth', 'AgeIssueResolved', 'WhichSurvey', 'PrimaryLast' ], axis = 1)
#Reassign columns to keyword code

# %%
pd.set_option('display.max.columns', 170)
pd.set_option('display.max.rows', 200)
SSBOS_19_KW.head()
SSBOS_19_KW2.head()
# Out:
#       RAA     RAB     RAC     RAD     RAE     RAF     RAG     RAH     RAI  \
# 0       1       2       1       1       1       3       0       3       3
# 1       1       3       2       0       1       0       0       7       2
# 2       1  #NULL!  #NULL!  #NULL!  #NULL!  #NULL!  #NULL!       6       0
# 3       1       2       2       1       0       2       0       2       0
# 4  #NULL!  #NULL!  #NULL!  #NULL!  #NULL!  #NULL!  #NULL!  #NULL!  #NULL!
#
#       VBI     VBJ     VBK     VBL     SUA     SUB     SUC     SUD     SUE  \
# 0       2       3       3       0       0       0       0  #NULL!  #NULL!
# 1       2       3       3       0       0       0       0  #NULL!  #NULL!
# 2  #NULL!  #NULL!  #NULL!  #NULL!  #NULL!  #NULL!  #NULL!  #NULL!  #NULL!
# 3       2       2       2       0       0  #NULL!       0  #NULL!  #NULL!
# 4  #NULL!  #NULL!  #NULL!  #NULL!  #NULL!       0       0  #NULL!  #NULL!
#
#       SUF     SUG     SUK     SUI     SUJ  SNA     SNB     SNC     SND  \
# ...

# %%
SSBOS_19_KW2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Columns: 143 entries, HEALTH_BRKFST to AgeGroup
# dtypes: object(143)
# memory usage: 199.0+ KB

# %%
SSBOS_19_KW2.rename(columns = {'HEALTH_BRKFST':'RAA', 'HEALTH_FRUIT':'RAB', 'HEALTH_VEG':'RAC', 'HEALTH_SODA':'RAD','HEALTH_FASTFOOD':'RAE',
                           'HEALTH_MILK':'RAF', 'HEALTH_VEND':'RAG', 'HEALTH_EXERCISE':'RAH', 'HEALTH_TEAM':'RAI', 'COLLEGE_APPLY':'RAJ',
                           'COLLEGE_SCHOLARSHIP':'RAK', 'SCHOOL_EDLVL':'AAA', 'SCHOOL_CARE':'AAB', 'SCHOOL_THINGS':'AAC', 
                           'SCHOOL_TRYLEARN':'AAD','SCHOOL_HMWRK':'AAE', 'SCHOOL_GIVEUP_R':'AAF','SCHOOL_HARDEST_HW':'AAG','SCHOOL_GRADES_ENG':'AAH',
                           'SCHOOL_GRADES_SCI':'AAI', 'SCHOOL_GRADES_MATH':'AAJ','SCHOOL_GRADES_COMP':'AAK', 'SCHOOL_FUN_READ':'AAL', 'SCHOOL_FUN_MATH':'AAM',                
                           'SCHOOL_FUN_SCI':'AAN', 'SCHOOL_HARD_READ':'AAO', 'SCHOOL_HARD_MATH':'AAP', 'SCHOOL_HARD_SCI':'AAQ', 'SCHOOL_STEM_UNDERSTAND':'AAR',         
                           'SCHOOL_STEM_GAMES':'AAS', 'SCHOOL_STEM_EXCITED':'AAT', 'SCHOOL_STEM_JOB':'AAU', 'SCHOOL_STEM_MADE':'AAV', 'SCHOOL_STEM_LEARN':'AAW',
                           'COLLEGE_EDUCATION':'AAX', 'COLLEGE_VISIT':'AAY', 'COLLEGE_TESTS':'AAZ',  'SCHOOL_SKIPDAY':'AAZZ','SCHOOL_SKIPCLASS':'AAZZZ', 'SCHOOL_SUSPEND':'JJA',                 
                           'SEX_REASONS_STD':'VBA', 'SEX_REASONS_PREG':'VBB','SEX_REASONS_SCHOOL':'VBC', 'SEX_REASONS_PERSON':'VBD', 'SEX_REASONS_TIME':'VBE', 'SEX_EVERSEX':'VBF',
                           'SEX_CONDOM':'VBG', 'SEX_BC':'VBH', 'SCHOOL_EXPELL':'JJB', 'SCHOOL_ARREST':'JJC', 'BODYIMAGE_PRTY_R':'VBI', 'BODYIMAGE_BODY':'VBJ','BODYIMAGE_TV_R':'VBK', 
                           'BODYIMAGE_DIET':'VBL','EE_PROGIRL_CANDO':'VBM','EE_PROGIRL_MAKEDIFF':'VBN','STANDUP_MAKEFUN':'VBO', 'RISKY_EVERSMOKE':'SUA', 'RISKY_EVERALC':'SUB',
                           'RISKY_EVERPOT':'SUC', 'RISKY_EVERVAPE':'SUD', 'RISKY_EVERPILLS':'SUE', 'RISKY_DAYSSMOKE':'SUF', 'RISKY_DAYSVAPE':'SUG', 'RISKY_DAYSALC':'SUH',
                           'RISKY_TIMESPOT':'SUI', 'RISKY_TIMESPILLS':'SUJ','RISKY_DAYSALC':'SUK', 'MENTALHEALTH_FRIEND':'SNA', 'MENTALHEALTH_FRIEND_1':'SNB','MENTALHEALTH_FRIEND_2':'SNC',
                           'MENTALHEALTH_FRIEND_3':'SND', 'MENTALHEALTH_FRIEND_4':'SNE', 'MENTALHEALTH_FRIEND_5':'SNF', 'MENTALHEALTH_FRIEND_6':'SNG', 'MENTALHEALTH_FRIEND_7':'SNH',
                           'MENTALHEALTH_SELF':'SNI', 'MENTALHEALTH_SELF_1':'SNJ', 'MENTALHEALTH_SELF_2':'SNK', 'MENTALHEALTH_SELF_3':'SNL', 'MENTALHEALTH_SELF_4':'SNM', 'MENTALHEALTH_SELF_5':'SNN',
                           'MENTALHEALTH_SELF_6':'SNO', 'SEX_PRESS_ROMP':'SNP',  'COLLEGE_INTERESTS':'SNQ', 'ADULT_CARES':'SNR', 'ADULT_JOB':'SNS', 'ADULT_UPSET':'SNT', 'ADULT_SUCCESS':'SNU',
                           'ADULT_BEST':'SNV', 'ADULT_TRUST':'SNW', 'EE_MNTR_DEPNDON':'SNX', 'EE_MNTR_RESPECT':'SNY', 'EE_MNTR_LISTEN':'SNZ', 'EE_MNTR_FUTURE':'SNZZ', 'EE_INTENT_IDEAS':'SNZZZ',
                           'DNP_BOUNCEBACK':'SEA', 'BULLY_HIT':'SEB', 'BULLY_HIT':'SEC', 'BULLY_VERB':'SED', 'BULLY_HIT_V':'SEE', 'BULLY_VERB_V':'SEF', 'BULLY_ELECT':'SEG', 'BULLY_FIGHT':'SEH',
                           'DNP_GIVEUP_R':'SEI', 'DNP_HARDWORK':'SEJ', 'SELFREG_TEMPER_R':'SEK', 'SELFREG_OVERIT':'SEL', 'SELFREG_MYWAY_R':'SEM', 'SELFREG_GETEVEN_R':'SEN','STANDUP_DOWN':'SEO',
                           'STANDUP_FAIR':'SEP', 'STANDUP_PICKED':'SEQ', 'EE_PROGIRL_FEELSAFE':'SER', 'EE_INTENT_TIME_R':'SES', 'EE_INTENT_BUILD_R':'SET', 'EE_INTER_TGTHR':'SEU', 
                           'EE_INTER_THINGS':'SEV','CIVIC_POSITIVE':'CTA', 'CIVIC_WAYS':'CTB', 'CIVIC_REALLIFE':'CTC', 'SOCIALR_PLANET':'CTD', 'SOCIALR_RESPON':'CTE', 'SOCIALR_BETTERPL':'CTF',
                           'VOLUNTEER_GI':'CTG', 'VOLUNTEER_COMM':'CTH', 'LEADER_GOAL':'LSA', 'LEADER_PEERS':'LSB', 'LEADER_ACTIVITIES':'LSC', 'EE_PROGIRL_LEADER':'LSD', 'EE_INTENT_DISORG_R':'LSE',
                           'EE_INTER_DECIDE':'LSF', 'DNP_ONTIME':'FPA', 'DNP_PLAN':'FPB', 'DNP_GIVEUP_R':'FPC', 'FUTURE_IMPACT':'FPD', 'FUTURE_OLDER':'FPE', 'FUTURE_HOPEFUL':'FPF', 'EE_PROGIRL_FUTURE':'FPG',
                           'MONEY_WELL':'FLA', 'MONEY_FUTURE':'FLB', 'MONEY_SPEND':'FLC', 'COLLEGE_COSTS':'FLD', 'SEX_PRESS_FRIEND':'SNZZA', }, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 SSBOS_19_KW2.rename(columns = {'HEALTH_BRKFST':'RAA', 'HEALTH_FRUIT':'RAB', 'HEALTH_VEG':'RAC', 'HEALTH_SODA':'RAD','HEALTH_FASTFOOD':'RAE',
#       2                            'HEALTH_MILK':'RAF', 'HEALTH_VEND':'RAG', 'HEALTH_EXERCISE':'RAH', 'HEALTH_TEAM':'RAI', 'COLLEGE_APPLY':'RAJ',
#       3                            'COLLEGE_SCHOLARSHIP':'RAK', 'SCHOOL_EDLVL':'AAA', 'SCHOOL_CARE':'AAB', 'SCHOOL_THINGS':'AAC',
#       4                            'SCHOOL_TRYLEARN':'AAD','SCHOOL_HMWRK':'AAE', 'SCHOOL_GIVEUP_R':'AAF','SCHOOL_HARDEST_HW':'AAG','SCHOOL_GRADES_ENG':'AAH',
#       5                            'SCHOOL_GRADES_SCI':'AAI', 'SCHOOL_GRADES_MATH':'AAJ','SCHOOL_GRADES_COMP':'AAK', 'SCHOOL_FUN_READ':'AAL', 'SCHOOL_FUN_MATH':'AAM',
# ...

# %%
SSBOS_19_KW2
# Out:
#         RAA     RAB     RAC     RAD     RAE     RAF     RAG     RAH     RAI  \
# 0         1       2       1       1       1       3       0       3       3
# 1         1       3       2       0       1       0       0       7       2
# 2         1  #NULL!  #NULL!  #NULL!  #NULL!  #NULL!  #NULL!       6       0
# 3         1       2       2       1       0       2       0       2       0
# 4    #NULL!  #NULL!  #NULL!  #NULL!  #NULL!  #NULL!  #NULL!  #NULL!  #NULL!
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 173       1       3       0       0       0       2       0       6       0
# 174       1       3       3       1       1       2       1       7       2
# 175       1       3       1       2       0       1       0       4       0
# 176       1       5       2       1       1       2       0       5       1
# 177       0       0       0       0       0       5       0       7       0
#
# ...

# %%
SSBOS_19_KW2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Columns: 143 entries, RAA to AgeGroup
# dtypes: object(143)
# memory usage: 199.0+ KB

# %%
SSBOS_19_KW2.nunique()
# Out:
# RAA         3
# RAB         7
# RAC         7
# RAD         7
# RAE         7
#            ..
# SNZZZ       5
# LSF         5
# SEU         5
# SEV         5
# AgeGroup    4
# Length: 143, dtype: int64

# %%
#created df specific to key word columns, reset index and ran counts.

# %%
RAA = SSBOS_19_KW2['RAA'].value_counts()  
RAA_df = pd.DataFrame(SSBOS_19_KW2['RAA'].value_counts()) 
RAA_df
RAA_index = RAA_df.reset_index()
RAA_index
RAA_counts=RAA_index.sort_values(by = 'RAA', ascending = True)
RAA_counts
# Out:
#       RAA  count
# 2  #NULL!     11
# 1       0     25
# 0       1    142

# %%
RAB = SSBOS_19_KW2['RAB'].value_counts()
RAB_df = pd.DataFrame(SSBOS_19_KW2['RAB'].value_counts()) 
RAB_df
RAB_index = RAB_df.reset_index()
RAB_index
RAB_counts=RAB_index.sort_values(by = 'RAB', ascending = True)
RAB_counts
# Out:
#       RAB  count
# 5  #NULL!     18
# 4       0     20
# 0       1     36
# 2       2     33
# 3       3     25
# 6       4     12
# 1       5     34

# %%
RAC = SSBOS_19_KW2['RAC'].value_counts()
RAC_df = pd.DataFrame(SSBOS_19_KW2['RAC'].value_counts()) 
RAC_df
RAC_index = RAC_df.reset_index()
RAC_index
RAC_counts=RAC_index.sort_values(by = 'RAC', ascending = True)
RAC_counts
# Out:
#       RAC  count
# 4  #NULL!     15
# 2       0     32
# 0       1     41
# 1       2     38
# 5       3     15
# 6       4     13
# 3       5     24

# %%
RAD = SSBOS_19_KW2['RAD'].value_counts()
RAD_df = pd.DataFrame(SSBOS_19_KW2['RAD'].value_counts()) 
RAD_df
RAD_index = RAD_df.reset_index()
RAD_index
RAD_counts=RAD_index.sort_values(by = 'RAD', ascending = True)
RAD_counts
# Out:
#       RAD  count
# 3  #NULL!     18
# 1       0     52
# 0       1     56
# 2       2     20
# 6       3      9
# 5       4     10
# 4       5     13

# %%
RAE = SSBOS_19_KW2['RAE'].value_counts()
RAE_df = pd.DataFrame(SSBOS_19_KW2['RAE'].value_counts()) 
RAE_df
RAE_index = RAE_df.reset_index()
RAE_index
RAE_counts=RAE_index.sort_values(by = 'RAE', ascending = True)
RAE_counts
# Out:
#       RAE  count
# 3  #NULL!     17
# 0       0     62
# 1       1     56
# 4       2     13
# 6       3      4
# 5       4      6
# 2       5     20

# %%
RAF = SSBOS_19_KW2['RAF'].value_counts()
RAF_df = pd.DataFrame(SSBOS_19_KW2['RAF'].value_counts()) 
RAF_df
RAF_index = RAF_df.reset_index()
RAF_index
RAF_counts=RAF_index.sort_values(by = 'RAF', ascending = True)
RAF_counts
# Out:
#       RAF  count
# 3  #NULL!     23
# 0       0     45
# 1       1     39
# 2       2     34
# 6       3      5
# 5       4     12
# 4       5     20

# %%
RAG = SSBOS_19_KW2['RAG'].value_counts()
RAG_df = pd.DataFrame(SSBOS_19_KW2['RAG'].value_counts()) 
RAG_df
RAG_index = RAG_df.reset_index()
RAG_index
RAG_counts=RAG_index.sort_values(by = 'RAG', ascending = True)
RAG_counts
# Out:
#       RAG  count
# 2  #NULL!     21
# 0       0     85
# 1       1     31
# 4       2     13
# 6       3      3
# 5       4     11
# 3       5     14

# %%
RAH = SSBOS_19_KW2['RAH'].value_counts()
RAH_df = pd.DataFrame(SSBOS_19_KW2['RAH'].value_counts()) 
RAH_df
RAH_index = RAH_df.reset_index()
RAH_index
RAH_counts=RAH_index.sort_values(by = 'RAH', ascending = True)
RAH_counts
# Out:
#       RAH  count
# 6  #NULL!      9
# 7       0      9
# 5       1     10
# 3       2     26
# 4       3     12
# 2       4     31
# 1       5     32
# 8       6      7
# 0       7     42

# %%
RAI = SSBOS_19_KW2['RAI'].value_counts()
RAI_df = pd.DataFrame(SSBOS_19_KW2['RAI'].value_counts()) 
RAI_df
RAI_index = RAI_df.reset_index()
RAI_index
RAI_counts=RAI_index.sort_values(by = 'RAI', ascending = True)
RAI_counts
# Out:
#       RAI  count
# 4  #NULL!     10
# 1       0     46
# 0       1     57
# 3       2     25
# 2       3     40

# %%
RAJ = SSBOS_19_KW2['RAJ'].value_counts()
RAJ_df = pd.DataFrame(SSBOS_19_KW2['RAJ'].value_counts()) 
RAJ_df
RAJ_index = RAJ_df.reset_index()
RAJ_index
RAJ_counts=RAJ_index.sort_values(by = 'RAJ', ascending = True)
RAJ_counts
# Out:
#       RAJ  count
# 0  #NULL!    168
# 4       0      1
# 1       1      4
# 2       2      3
# 3       3      2

# %%
RAK = SSBOS_19_KW2['RAK'].value_counts()
RAK_df = pd.DataFrame(SSBOS_19_KW2['RAK'].value_counts()) 
RAK_df
RAK_index = RAK_df.reset_index()
RAK_index
RAK_counts=RAK_index.sort_values(by = 'RAK', ascending = True)
RAK_counts
# Out:
#       RAK  count
# 0  #NULL!    168
# 4       0      1
# 1       1      4
# 2       2      3
# 3       3      2

# %%
AAA = SSBOS_19_KW2['AAA'].value_counts()  
AAA_df = pd.DataFrame(SSBOS_19_KW2['AAA'].value_counts()) 
AAA_df
AAA_index = AAA_df.reset_index()
AAA_index
AAA_counts=AAA_index.sort_values(by = 'AAA', ascending = True)
AAA_counts
# Out:
#       AAA  count
# 5  #NULL!     11
# 4       0     14
# 6       2      8
# 3       3     24
# 2       4     24
# 1       5     29
# 0       6     68

# %%
AAB = SSBOS_19_KW2['AAB'].value_counts()  
AAB_df = pd.DataFrame(SSBOS_19_KW2['AAB'].value_counts()) 
AAB_df
AAB_index = AAB_df.reset_index()
AAB_index
AAB_counts=AAB_index.sort_values(by = 'AAB', ascending = True)
AAB_counts
# Out:
#       AAB  count
# 3  #NULL!      5
# 2       1     11
# 1       2     49
# 0       3    113

# %%
AAC = SSBOS_19_KW2['AAC'].value_counts()  
AAC_df = pd.DataFrame(SSBOS_19_KW2['AAC'].value_counts()) 
AAC_df
AAC_index = AAC_df.reset_index()
AAC_index
AAC_counts=AAC_index.sort_values(by = 'AAC', ascending = True)
AAC_counts
# Out:
#       AAC  count
# 3  #NULL!      7
# 4       0      5
# 2       1     17
# 1       2     57
# 0       3     92

# %%
AAD = SSBOS_19_KW2['AAD'].value_counts()  
AAD_df = pd.DataFrame(SSBOS_19_KW2['AAD'].value_counts()) 
AAD_df
AAD_index = AAD_df.reset_index()
AAD_index
AAD_counts=AAD_index.sort_values(by = 'AAD', ascending = True)
AAD_counts
# Out:
#       AAD  count
# 3  #NULL!     10
# 4       0      2
# 2       1     12
# 1       2     56
# 0       3     98

# %%
AAE = SSBOS_19_KW2['AAE'].value_counts()  
AAE_df = pd.DataFrame(SSBOS_19_KW2['AAE'].value_counts()) 
AAE_df
AAE_index = AAE_df.reset_index()
AAE_index
AAE_counts=AAE_index.sort_values(by = 'AAE', ascending = True)
AAE_counts
# Out:
#       AAE  count
# 3  #NULL!     11
# 4       0      9
# 2       1     24
# 1       2     56
# 0       3     78

# %%
AAF = SSBOS_19_KW2['AAF'].value_counts()  
AAF_df = pd.DataFrame(SSBOS_19_KW2['AAF'].value_counts()) 
AAF_df
AAF_index = AAF_df.reset_index()
AAF_index
AAF_counts=AAF_index.sort_values(by = 'AAF', ascending = True)
AAF_counts
# Out:
#       AAF  count
# 4  #NULL!      8
# 3       0     19
# 1       1     25
# 2       2     25
# 0       3    101

# %%
AAG = SSBOS_19_KW2['AAG'].value_counts()  
AAG_df = pd.DataFrame(SSBOS_19_KW2['AAG'].value_counts()) 
AAG_df
AAG_index = AAG_df.reset_index()
AAG_index
AAG_counts=AAG_index.sort_values(by = 'AAG', ascending = True)
AAG_counts
# Out:
#       AAG  count
# 3  #NULL!     13
# 4       0      5
# 2       1     15
# 1       2     66
# 0       3     79

# %%
AAH = SSBOS_19_KW2['AAH'].value_counts()  
AAH_df = pd.DataFrame(SSBOS_19_KW2['AAH'].value_counts()) 
AAH_df
AAH_index = AAH_df.reset_index()
AAH_index
AAH_counts=AAH_index.sort_values(by = 'AAH', ascending = True)
AAH_counts
# Out:
#       AAH  count
# 4  #NULL!      7
# 7       0      1
# 6       1      1
# 2       2     16
# 1       3     53
# 0       4     85
# 5      95      3
# 3      96     12

# %%
AAI = SSBOS_19_KW2['AAI'].value_counts()  
AAI_df = pd.DataFrame(SSBOS_19_KW2['AAI'].value_counts()) 
AAI_df
AAI_index = AAI_df.reset_index()
AAI_index
AAI_counts=AAI_index.sort_values(by = 'AAI', ascending = True)
AAI_counts
# Out:
#       AAI  count
# 0  #NULL!    168
# 4       1      1
# 3       2      2
# 2       3      3
# 1       4      4

# %%
AAJ = SSBOS_19_KW2['AAJ'].value_counts()  
AAJ_df = pd.DataFrame(SSBOS_19_KW2['AAJ'].value_counts()) 
AAJ_df
AAJ_index = AAJ_df.reset_index()
AAJ_index
AAJ_counts=AAJ_index.sort_values(by = 'AAJ', ascending = True)
AAJ_counts
# Out:
#       AAJ  count
# 4  #NULL!      7
# 7       0      1
# 5       1      3
# 2       2     27
# 1       3     59
# 0       4     67
# 6      95      3
# 3      96     11

# %%
AAK = SSBOS_19_KW2['AAK'].value_counts()  
AAK_df = pd.DataFrame(SSBOS_19_KW2['AAK'].value_counts()) 
AAK_df
AAK_index = AAK_df.reset_index()
AAK_index
AAK_counts=AAK_index.sort_values(by = 'AAK', ascending = True)
AAK_counts
# Out:
#       AAK  count
# 3  #NULL!      8
# 2       0     16
# 0       1    103
# 1       2     51

# %%
AAL = SSBOS_19_KW2['AAL'].value_counts()  
AAL_df = pd.DataFrame(SSBOS_19_KW2['AAL'].value_counts()) 
AAL_df
AAL_index = AAL_df.reset_index()
AAL_index
AAL_counts=AAL_index.sort_values(by = 'AAL', ascending = True)
AAL_counts
# Out:
#       AAL  count
# 4  #NULL!      8
# 3       0     19
# 2       1     24
# 0       2     71
# 1       3     56

# %%
AAM = SSBOS_19_KW2['AAM'].value_counts()  
AAM_df = pd.DataFrame(SSBOS_19_KW2['AAM'].value_counts()) 
AAM_df
AAM_index = AAM_df.reset_index()
AAM_index
AAM_counts=AAM_index.sort_values(by = 'AAM', ascending = True)
AAM_counts
# Out:
#       AAM  count
# 4  #NULL!      9
# 2       0     23
# 3       1     23
# 0       2     69
# 1       3     54

# %%
AAN = SSBOS_19_KW2['AAN'].value_counts()  
AAN_df = pd.DataFrame(SSBOS_19_KW2['AAN'].value_counts()) 
AAN_df
AAN_index = AAN_df.reset_index()
AAN_index
AAN_counts=AAN_index.sort_values(by = 'AAN', ascending = True)
AAN_counts
# Out:
#       AAN  count
# 3  #NULL!     12
# 4       0      8
# 2       1     14
# 0       2     80
# 1       3     64

# %%
AAO = SSBOS_19_KW2['AAO'].value_counts()  
AAO_df = pd.DataFrame(SSBOS_19_KW2['AAO'].value_counts()) 
AAO_df
AAO_index = AAO_df.reset_index()
AAO_index
AAO_counts=AAO_index.sort_values(by = 'AAO', ascending = True)
AAO_counts
# Out:
#       AAO  count
# 0  #NULL!    168
# 2       1      5
# 1       3      5

# %%
AAP = SSBOS_19_KW2['AAP'].value_counts()  
AAP_df = pd.DataFrame(SSBOS_19_KW2['AAP'].value_counts()) 
AAP_df
AAP_index = AAP_df.reset_index()
AAP_index
AAP_counts=AAP_index.sort_values(by = 'AAP', ascending = True)
AAP_counts
# Out:
#       AAP  count
# 0  #NULL!    168
# 1       1      5
# 3       2      2
# 2       3      3

# %%
AAQ = SSBOS_19_KW2['AAQ'].value_counts()  
AAQ_df = pd.DataFrame(SSBOS_19_KW2['AAQ'].value_counts()) 
AAQ_df
AAQ_index = AAQ_df.reset_index()
AAQ_index
AAQ_counts=AAQ_index.sort_values(by = 'AAQ', ascending = True)
AAQ_counts
# Out:
#       AAQ  count
# 0  #NULL!    168
# 1       1      5
# 3       2      1
# 2       3      4

# %%
AAR = SSBOS_19_KW2['AAR'].value_counts()  
AAR_df = pd.DataFrame(SSBOS_19_KW2['AAR'].value_counts()) 
AAR_df
AAR_index = AAR_df.reset_index()
AAR_index
AAR_counts=AAR_index.sort_values(by = 'AAR', ascending = True)
AAR_counts
# Out:
#       AAR  count
# 4  #NULL!      7
# 2       0     11
# 3       1     10
# 0       2     81
# 1       3     69

# %%
AAS = SSBOS_19_KW2['AAS'].value_counts()  
AAS_df = pd.DataFrame(SSBOS_19_KW2['AAS'].value_counts()) 
AAS_df
AAS_index = AAS_df.reset_index()
AAS_index
AAS_counts=AAS_index.sort_values(by = 'AAS', ascending = True)
AAS_counts
# Out:
#       AAS  count
# 4  #NULL!      9
# 3       0     11
# 2       1     26
# 0       2     72
# 1       3     60

# %%
AAT = SSBOS_19_KW2['AAT'].value_counts()  
AAT_df = pd.DataFrame(SSBOS_19_KW2['AAT'].value_counts()) 
AAT_df
AAT_index = AAT_df.reset_index()
AAT_index
AAT_counts=AAT_index.sort_values(by = 'AAT', ascending = True)
AAT_counts
# Out:
#       AAT  count
# 4  #NULL!     11
# 3       0     15
# 2       1     32
# 0       2     69
# 1       3     51

# %%
AAU = SSBOS_19_KW2['AAU'].value_counts()  
AAU_df = pd.DataFrame(SSBOS_19_KW2['AAU'].value_counts()) 
AAU_df
AAU_index = AAU_df.reset_index()
AAU_index
AAU_counts=AAU_index.sort_values(by = 'AAU', ascending = True)
AAU_counts
# Out:
#       AAU  count
# 4  #NULL!      8
# 3       0     28
# 0       1     57
# 1       2     46
# 2       3     39

# %%
AAV = SSBOS_19_KW2['AAV'].value_counts()  
AAV_df = pd.DataFrame(SSBOS_19_KW2['AAV'].value_counts()) 
AAV_df
AAV_index = AAV_df.reset_index()
AAV_index
AAV_counts=AAV_index.sort_values(by = 'AAV', ascending = True)
AAV_counts
# Out:
#       AAV  count
# 4  #NULL!     10
# 3       0     10
# 2       1     20
# 1       2     64
# 0       3     74

# %%
SSBOS_19_KW2
# Out:
#         RAA     RAB     RAC     RAD     RAE     RAF     RAG     RAH     RAI  \
# 0         1       2       1       1       1       3       0       3       3
# 1         1       3       2       0       1       0       0       7       2
# 2         1  #NULL!  #NULL!  #NULL!  #NULL!  #NULL!  #NULL!       6       0
# 3         1       2       2       1       0       2       0       2       0
# 4    #NULL!  #NULL!  #NULL!  #NULL!  #NULL!  #NULL!  #NULL!  #NULL!  #NULL!
# 5         1       4       3       1       0       1       0       5       0
# 6         1       1       0       0       0       0       0       2       1
# 7         1       0       0       0       3       0       1       5       1
# 8         1       5       0       1       1       1       4       7       3
# 9         1       3       3       0       0       3       0       4       1
# 10        1       3       4       4       4       4       4       3       1
# ...

# %%
AAW = SSBOS_19_KW2['AAW'].value_counts()  
AAW_df = pd.DataFrame(SSBOS_19_KW2['AAW'].value_counts()) 
AAW_df
AAW_index = AAW_df.reset_index()
AAW_index
AAW_counts=AAW_index.sort_values(by = 'AAW', ascending = True)
AAW_counts
# Out:
#       AAW  count
# 4  #NULL!     10
# 3       0     19
# 2       1     33
# 0       2     61
# 1       3     55

# %%
AAX = SSBOS_19_KW2['AAX'].value_counts()  
AAX_df = pd.DataFrame(SSBOS_19_KW2['AAX'].value_counts()) 
AAX_df
AAX_index = AAX_df.reset_index()
AAX_index
AAX_counts=AAX_index.sort_values(by = 'AAX', ascending = True)
AAX_counts
# Out:
#       AAX  count
# 0  #NULL!    168
# 3       1      3
# 1       2      4
# 2       3      3

# %%
AAY = SSBOS_19_KW2['AAY'].value_counts()  
AAY_df = pd.DataFrame(SSBOS_19_KW2['AAY'].value_counts()) 
AAY_df
AAY_index = AAY_df.reset_index()
AAY_index
AAY_counts=AAY_index.sort_values(by = 'AAY', ascending = True)
AAY_counts
# Out:
#       AAY  count
# 0  #NULL!    168
# 3       0      1
# 2       1      4
# 1       2      4
# 4       3      1

# %%
AAZ = SSBOS_19_KW2['AAZ'].value_counts()  
AAZ_df = pd.DataFrame(SSBOS_19_KW2['AAZ'].value_counts()) 
AAZ_df
AAZ_index = AAZ_df.reset_index()
AAZ_index
AAZ_counts=AAZ_index.sort_values(by = 'AAZ', ascending = True)
AAZ_counts
# Out:
#       AAZ  count
# 0  #NULL!    168
# 3       0      2
# 1       1      4
# 2       2      3
# 4       3      1

# %%
AAZZ = SSBOS_19_KW2['AAZZ'].value_counts()  
AAZZ_df = pd.DataFrame(SSBOS_19_KW2['AAZZ'].value_counts()) 
AAZZ_df
AAZZ_index = AAZZ_df.reset_index()
AAZZ_index
AAZZ_counts=AAZZ_index.sort_values(by = 'AAZZ', ascending = True)
AAZZ_counts
# Out:
#      AAZZ  count
# 0  #NULL!    168
# 2       0      4
# 1       1      6

# %%
AAZZZ = SSBOS_19_KW2['AAZZZ'].value_counts()  
AAZZZ_df = pd.DataFrame(SSBOS_19_KW2['AAZZZ'].value_counts()) 
AAZZZ_df
AAZZZ_index = AAZZZ_df.reset_index()
AAZZZ_index
AAZZZ_counts=AAZZZ_index.sort_values(by = 'AAZZZ', ascending = True)
AAZZZ_counts
# Out:
#     AAZZZ  count
# 0  #NULL!    168
# 1       0      5
# 2       1      4
# 3       3      1

# %%
JJA_C_df= SSBOS_19_KW2[['JJA', 'JJB', 'JJC']]
JJA_C_df
JJA_C_df_index =JJA_C_df.reset_index()
JJA_C_df_index
JJA_C_df_counts=JJA_C_df_index.sort_values(by = ['JJA', 'JJB', 'JJC'], ascending =[False, False, False])
JJA_C_df_counts
# Out:
#      index     JJA     JJB     JJC
# 155    155       2       0       0
# 119    119       1       0       0
# 17      17       0       0       0
# 18      18       0       0       0
# 32      32       0       0       0
# ..     ...     ...     ...     ...
# 173    173  #NULL!  #NULL!  #NULL!
# 174    174  #NULL!  #NULL!  #NULL!
# 175    175  #NULL!  #NULL!  #NULL!
# 176    176  #NULL!  #NULL!  #NULL!
# 177    177  #NULL!  #NULL!  #NULL!
#
# [178 rows x 4 columns]

# %%
#sorted_df = df.sort_values(by = ['Rank', 'Age'], ascending = [True, False], na_position = 'first')
print(sorted_df)

# %%
pivot1 = pd.pivot_table(JJA_C_df, index = ['JJA', 'JJB', 'JJC'])
pivot1
# Out:
# Empty DataFrame
# Columns: []
# Index: [(#NULL!, #NULL!, #NULL!), (0, 0, 0), (1, 0, 0), (2, 0, 0)]

# %%
JJA_C_df['JJA'].value_counts()
# Out:
# JJA
# #NULL!    168
# 0           8
# 1           1
# 2           1
# Name: count, dtype: int64

# %%
JJA_C_df['JJB'].value_counts()
# Out:
# JJB
# #NULL!    168
# 0          10
# Name: count, dtype: int64

# %%
JJA_C_df['JJC'].value_counts()
# Out:
# JJC
# #NULL!    168
# 0          10
# Name: count, dtype: int64

# %%
SNA_ZA_df= SSBOS_19_KW2[['SNA','SNB', 'SNC', 'SND', 'SNE', 'SNF', 'SNG', 'SNH', 'SNI', 'SNJ', 'SNK', 'SNL', 'SNM', 'SNN', 'SNO', 'SNP', 'SNZZA', 'SNQ', 'SNR', 'SNS', 'SNT', 'SNU', 'SNV', 'SNW', 'SEO', 'SEP', 'SEQ', 'SNX', 'SNY', 'SNZ', 'SNZZ', 'SNZZZ']]
SNA_ZA_df
SNA_ZA_df_index =SNA_ZA_df.reset_index()
SNA_ZA_df_index
SNA_ZA_df_counts=SNA_ZA_df_index.sort_values(by = ['SNA','SNB', 'SNC', 'SND', 'SNE', 'SNF', 'SNG', 'SNH', 'SNI', 'SNJ', 'SNK', 'SNL', 'SNM', 'SNN', 'SNO', 'SNP', 'SNZZA', 'SNQ', 'SNR', 'SNS', 'SNT', 'SNU', 'SNV', 'SNW', 'SEO', 'SEP', 'SEQ', 'SNX', 'SNY', 'SNZ', 'SNZZ', 'SNZZZ'])
SNA_ZA_df_counts
# Out:
#      index                                                SNA     SNB     SNC  \
# 119    119  Offer my support.\nTell them to get help from ...       1       0
# 80      80  Offer my support.\nTell them to talk to a pare...       1       0
# 152    152  Offer my support.\nTell them to talk to a teac...       1       1
# 18      18  Offer my support.\nTell them to talk to a teac...       1       1
# 17      17  Offer my support.\nTell them to talk to a teac...       1       1
# ..     ...                                                ...     ...     ...
# 157    157                                                NaN  #NULL!  #NULL!
# 166    166                                                NaN  #NULL!  #NULL!
# 69      69                                                NaN  #NULL!  #NULL!
# 91      91                                                NaN  #NULL!  #NULL!
# 159    159                                                NaN  #NULL!  #NULL!
#
# ...

# %%
SNA_ZA_df['SNA'].value_counts()
# Out:
# SNA
# Offer my support.\nTell them to talk to a teacher or another adult at school.\nTell them to talk to a parent or someone else in their family.\nTell them to get help from a counselor, doctor, or therapist.\nTell them to talk to an adult at Girls Inc.                                                                          3
# Offer my support.\nTell them to talk to a teacher or another adult at school.\nTell them to talk to a parent or someone else in their family.\nTell them to get help from a counselor, doctor, or therapist.                                                                                                                       1
# Offer my support.\nTell them to talk to a teacher or another adult at school.\nTell them to talk to a parent or someone else in their family.                                                                                                                                                                                      1
# ...

# %%
SNA_ZA_df['SNB'].value_counts()
# Out:
# SNB
# #NULL!    168
# 1          10
# Name: count, dtype: int64

# %%
SNA_ZA_df['SNC'].value_counts()
# Out:
# SNC
# #NULL!    168
# 1           8
# 0           2
# Name: count, dtype: int64

# %%
SNA_ZA_df['SND'].value_counts()
# Out:
# SND
# #NULL!    168
# 1           8
# 0           2
# Name: count, dtype: int64

# %%
SNA_ZA_df['SNE'].value_counts()
# Out:
# SNE
# #NULL!    168
# 1           7
# 0           3
# Name: count, dtype: int64

# %%
SNA_ZA_df['SNF'].value_counts()
# Out:
# SNF
# #NULL!    168
# 1           7
# 0           3
# Name: count, dtype: int64

# %%
SNA_ZA_df['SNG'].value_counts()
# Out:
# SNG
# #NULL!    168
# 0           8
# 1           2
# Name: count, dtype: int64

# %%
SNA_ZA_df['SNH'].value_counts()
# Out:
# SNH
# #NULL!    168
# 0           8
# 1           2
# Name: count, dtype: int64

# %%
SNA_ZA_df['SNI'].value_counts()
# Out:
# SNI
# Talk to my friends.\nTalk to a teacher or another adult at school.\nTalk to my parents or someone else in my family.\nGet help from a counselor, doctor or therapist.\nTalk to an adult at Girls Inc.                          2
# Talk to my friends.\nGet help from a counselor, doctor or therapist.\nTalk to an adult at Girls Inc.                                                                                                                           2
# Talk to my friends.\nTalk to my parents or someone else in my family.\nGet help from a counselor, doctor or therapist.                                                                                                         1
# Talk to my friends.\nTalk to a teacher or another adult at school.\nTalk to my parents or someone else in my family.\nGet help from a counselor, doctor or therapist.                                                          1
# ...

# %%
SNA_ZA_df['SNJ'].value_counts()
# Out:
# SNJ
# #NULL!    168
# 1          10
# Name: count, dtype: int64

# %%
SNA_ZA_df['SNK'].value_counts()
# Out:
# SNK
# #NULL!    168
# 0           5
# 1           5
# Name: count, dtype: int64

# %%
SNA_ZA_df['SNL'].value_counts()
# Out:
# SNL
# #NULL!    168
# 1           8
# 0           2
# Name: count, dtype: int64

# %%
SNA_ZA_df['SNM'].value_counts()
# Out:
# SNM
# #NULL!    168
# 1           8
# 0           2
# Name: count, dtype: int64

# %%
SNA_ZA_df['SNN'].value_counts()
# Out:
# SNN
# #NULL!    168
# 1           7
# 0           3
# Name: count, dtype: int64

# %%
SNA_ZA_df['SNO'].value_counts()
# Out:
# SNO
# #NULL!    168
# 0           8
# 1           2
# Name: count, dtype: int64

# %%
SNA_ZA_df['SNP'].value_counts()
# Out:
# SNP
# #NULL!    168
# 0           8
# 95          1
# 1           1
# Name: count, dtype: int64

# %%
SNA_ZA_df['SNQ'].value_counts()
# Out:
# SNQ
# #NULL!    168
# 2           4
# 1           3
# 3           2
# 0           1
# Name: count, dtype: int64

# %%
SNA_ZA_df['SNR'].value_counts()
# Out:
# SNR
# 3         119
# 2          41
# #NULL!      7
# 1           6
# 0           5
# Name: count, dtype: int64

# %%
SNA_ZA_df['SNS'].value_counts()
# Out:
# SNS
# 3         103
# 2          57
# #NULL!      9
# 1           7
# 0           2
# Name: count, dtype: int64

# %%
SNA_ZA_df['SNT'].value_counts()
# Out:
# SNT
# 3         102
# 2          55
# #NULL!     10
# 1           8
# 0           3
# Name: count, dtype: int64

# %%
SNA_ZA_df['SNU'].value_counts()
# Out:
# SNU
# 3         106
# 2          49
# #NULL!     12
# 1           9
# 0           2
# Name: count, dtype: int64

# %%
SNA_ZA_df['SNV'].value_counts()
# Out:
# SNV
# 3         118
# 2          36
# #NULL!     13
# 1           7
# 0           4
# Name: count, dtype: int64

# %%
SNA_ZA_df['SNW'].value_counts()
# Out:
# SNW
# 3         108
# 2          40
# #NULL!     14
# 1           9
# 0           7
# Name: count, dtype: int64

# %%
SNA_ZA_df['SNX'].value_counts()
# Out:
# SNX
# 3         98
# 2         66
# 0          7
# #NULL!     5
# 1          2
# Name: count, dtype: int64

# %%
SNA_ZA_df['SNY'].value_counts()
# Out:
# SNY
# 3         105
# 2          59
# #NULL!      8
# 0           5
# 1           1
# Name: count, dtype: int64

# %%
SNA_ZA_df['SNZ'].value_counts()
# Out:
# SNZ
# 3         79
# 2         78
# #NULL!     9
# 1          7
# 0          5
# Name: count, dtype: int64

# %%
SNA_ZA_df['SNZZ'].value_counts()
# Out:
# SNZZ
# 2         80
# 3         72
# #NULL!    11
# 0          8
# 1          7
# Name: count, dtype: int64

# %%
SNA_ZA_df['SNZZA'].value_counts()
# Out:
# SNZZA
# #NULL!    168
# 0           8
# 1           2
# Name: count, dtype: int64

# %%
SNA_ZA_df['SNZZZ'].value_counts()
# Out:
# SNZZZ
# 3         87
# 2         55
# #NULL!    21
# 1          9
# 0          6
# Name: count, dtype: int64

# %%
SUA_df= SSBOS_19_KW2[['SUA', 'SUB', 'SUC', 'SUD', 'SUE', 'SUF', 'SUG', 'SUH', 'SUK', 'SUI', 'SUJ']]
SUA_df
SUA_df_index =SUA_ZA_df.reset_index()
SUA_df_index
SUA_df_counts=SUA_ZA_df_index.sort_values(by = ['SUA', 'SUB', 'SUC', 'SUD', 'SUE', 'SUF', 'SUG', 'SUH', 'SUK', 'SUI', 'SUJ'])
SUA_df_counts
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 SUA_J_df= SSBOS_19_KW2[['SUA', 'SUB', 'SUC', 'SUD', 'SUE', 'SUF', 'SUG', 'SUH', 'SUK', 'SUI', 'SUJ']]
#       2 SUA_J_df
#       3 SUA_J_df_index =SUA_J_df.reset_index()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3767, in DataFrame.__getitem__(self, key)
#    3765     if is_iterator(key):
#    3766         key = list(key)
# -> 3767     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3769 # take() does not accept boolean indexers
#    3770 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5877, in Index._get_indexer_strict(self, key, axis_name)
#    5874 else:
#    5875     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5877 self._raise_if_missing(keyarr, indexer, axis_name)
# ...

# %%
#Identified duplicate mistake

# %%
SUA_J_df['SUA'].value_counts()
# Out:
# SUA
# 0         132
# #NULL!     36
# 1           9
# 2           1
# Name: count, dtype: int64

# %%
SUA_J_df['SUB'].value_counts()
# Out:
# SUB
# 0         122
# #NULL!     37
# 1          19
# Name: count, dtype: int64

# %%
SUA_J_df['SUC'].value_counts()
# Out:
# SUC
# 0         135
# #NULL!     35
# 95          6
# 1           2
# Name: count, dtype: int64

# %%
SUA_J_df['SUD'].value_counts()
# Out:
# SUD
# #NULL!    168
# 0           8
# 1           2
# Name: count, dtype: int64

# %%
SUA_J_df['SUE'].value_counts()
# Out:
# SUE
# #NULL!    168
# 0          10
# Name: count, dtype: int64

# %%
SUA_J_df['SUF'].value_counts()
# Out:
# SUF
# #NULL!    175
# 1           2
# 0           1
# Name: count, dtype: int64

# %%
SUA_J_df['SUG'].value_counts()
# Out:
# SUG
# #NULL!    176
# 1           2
# Name: count, dtype: int64

# %%
SUA_J_df['SUK'].value_counts()
# Out:
# SUK
# #NULL!    174
# 0           2
# 1           2
# Name: count, dtype: int64

# %%
SUA_J_df['SUI'].value_counts()
# Out:
# SUI
# #NULL!    178
# Name: count, dtype: int64

# %%
SUA_J_df['SUJ'].value_counts()
# Out:
# SUJ
# #NULL!    178
# Name: count, dtype: int64
