# %%
import pandas as pd

# %%
SSBOS_19_PPSN = pd.read_csv(r"C:\Users\parml\Desktop\GI\SSBOS_PP\2019_SN_SSBOSPPGH.csv")

# %%
SSBOS_19_PPSN.head()
# Out:
#   RGIStandards IGIStandards MENTALHEALTH_FRIEND MENTALHEALTH_FRIEND_1  \
# 0            7            4                 NaN                #NULL!
# 1            7            5                 NaN                #NULL!
# 2            7            5                 NaN                #NULL!
# 3            2            1                 NaN                #NULL!
# 4            5            2                 NaN                #NULL!
#
#   MENTALHEALTH_FRIEND_2 MENTALHEALTH_FRIEND_3 MENTALHEALTH_FRIEND_4  \
# 0                #NULL!                #NULL!                #NULL!
# 1                #NULL!                #NULL!                #NULL!
# 2                #NULL!                #NULL!                #NULL!
# 3                #NULL!                #NULL!                #NULL!
# 4                #NULL!                #NULL!                #NULL!
#
#   MENTALHEALTH_FRIEND_5 MENTALHEALTH_FRIEND_6 MENTALHEALTH_FRIEND_7  ...  \
# ...

# %%
pd.set_option('display.max.columns', 170)
pd.set_option('display.max.rows', 200)
SSBOS_19_PPSN.head()
# Out:
#   RGIStandards IGIStandards MENTALHEALTH_FRIEND MENTALHEALTH_FRIEND_1  \
# 0            7            4                 NaN                #NULL!
# 1            7            5                 NaN                #NULL!
# 2            7            5                 NaN                #NULL!
# 3            2            1                 NaN                #NULL!
# 4            5            2                 NaN                #NULL!
#
#   MENTALHEALTH_FRIEND_2 MENTALHEALTH_FRIEND_3 MENTALHEALTH_FRIEND_4  \
# 0                #NULL!                #NULL!                #NULL!
# 1                #NULL!                #NULL!                #NULL!
# 2                #NULL!                #NULL!                #NULL!
# 3                #NULL!                #NULL!                #NULL!
# 4                #NULL!                #NULL!                #NULL!
#
#   MENTALHEALTH_FRIEND_5 MENTALHEALTH_FRIEND_6 MENTALHEALTH_FRIEND_7  \
# ...

# %%
Race_Info = SSBOS_19_PPSN.groupby(['RGIStandards','IGIStandards', 'MENTALHEALTH_FRIEND_1']).size() 
#Grouped by columns
Race_Info
# Out:
# RGIStandards  IGIStandards  MENTALHEALTH_FRIEND_1
# #NULL!        2             #NULL!                    1
#               4             1                         1
# 1             4             #NULL!                    1
# 2             #NULL!        #NULL!                    5
#               1             #NULL!                   13
#               2             #NULL!                    9
#               3             #NULL!                    6
#                             1                         1
#               4             #NULL!                    5
#                             1                         2
#               5             #NULL!                    2
#               99            #NULL!                    1
# 3             #NULL!        #NULL!                    2
#               1             1                         1
#               2             #NULL!                    3
#               3             #NULL!                    1
# ...

# %%
SSBOS_19_PPSN.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 31 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   RGIStandards           178 non-null    object
#  1   IGIStandards           178 non-null    object
#  2   MENTALHEALTH_FRIEND    10 non-null     object
#  3   MENTALHEALTH_FRIEND_1  178 non-null    object
#  4   MENTALHEALTH_FRIEND_2  178 non-null    object
#  5   MENTALHEALTH_FRIEND_3  178 non-null    object
#  6   MENTALHEALTH_FRIEND_4  178 non-null    object
#  7   MENTALHEALTH_FRIEND_5  178 non-null    object
#  8   MENTALHEALTH_FRIEND_6  178 non-null    object
#  9   MENTALHEALTH_FRIEND_7  178 non-null    object
#  10  MENTALHEALTH_SELF      10 non-null     object
#  11  MENTALHEALTH_SELF_1    178 non-null    object
#  12  MENTALHEALTH_SELF_2    178 non-null    object
#  13  MENTALHEALTH_SELF_3    178 non-null    object
# ...

# %%
SSBOS_19_PPSN.nunique()
#identify the range of possible responses
# Out:
# RGIStandards             8
# IGIStandards             7
# MENTALHEALTH_FRIEND      8
# MENTALHEALTH_FRIEND_1    2
# MENTALHEALTH_FRIEND_2    3
# MENTALHEALTH_FRIEND_3    3
# MENTALHEALTH_FRIEND_4    3
# MENTALHEALTH_FRIEND_5    3
# MENTALHEALTH_FRIEND_6    3
# MENTALHEALTH_FRIEND_7    3
# MENTALHEALTH_SELF        8
# MENTALHEALTH_SELF_1      2
# MENTALHEALTH_SELF_2      3
# MENTALHEALTH_SELF_3      3
# MENTALHEALTH_SELF_4      3
# MENTALHEALTH_SELF_5      3
# MENTALHEALTH_SELF_6      3
# SEX_PRESS_ROMP           4
# SEX_PRESS_FRIEND         3
# COLLEGE_INTERESTS        5
# ADULT_CARES              5
# ADULT_JOB                5
# ADULT_UPSET              5
# ADULT_SUCCESS            5
# ADULT_BEST               5
# ADULT_TRUST              5
# EE_MNTR_DEPNDON          5
# EE_MNTR_RESPECT          5
# EE_MNTR_LISTEN           5
# EE_MNTR_FUTURE           5
# EE_INTENT_IDEAS          5
# dtype: int64

# %%
SSBOS_19_PPSN.rename(columns = {'MENTALHEALTH_FRIEND':'SNA', 'MENTALHEALTH_FRIEND_1':'SNB','MENTALHEALTH_FRIEND_2':'SNC',
                           'MENTALHEALTH_FRIEND_3':'SND', 'MENTALHEALTH_FRIEND_4':'SNE', 'MENTALHEALTH_FRIEND_5':'SNF', 'MENTALHEALTH_FRIEND_6':'SNG', 'MENTALHEALTH_FRIEND_7':'SNH',
                           'MENTALHEALTH_SELF':'SNI', 'MENTALHEALTH_SELF_1':'SNJ', 'MENTALHEALTH_SELF_2':'SNK', 'MENTALHEALTH_SELF_3':'SNL', 'MENTALHEALTH_SELF_4':'SNM', 'MENTALHEALTH_SELF_5':'SNN',
                           'MENTALHEALTH_SELF_6':'SNO', 'SEX_PRESS_ROMP':'SNP',  'COLLEGE_INTERESTS':'SNQ', 'ADULT_CARES':'SNR', 'ADULT_JOB':'SNS', 'ADULT_UPSET':'SNT', 'ADULT_SUCCESS':'SNU',
                           'ADULT_BEST':'SNV', 'ADULT_TRUST':'SNW', 'EE_MNTR_DEPNDON':'SNX', 'EE_MNTR_RESPECT':'SNY', 'EE_MNTR_LISTEN':'SNZ', 'EE_MNTR_FUTURE':'SNZZ', 'EE_INTENT_IDEAS':'SNZZZ',
                           'SEX_PRESS_FRIEND':'SNZZA', }, inplace = True)
#Renamed colums to connect to keyword

# %%
SSBOS_19_PPSN
# Out:
#     RGIStandards IGIStandards  \
# 0              7            4
# 1              7            5
# 2              7            5
# 3              2            1
# 4              5            2
# 5              7            5
# 6              5           99
# 7              7            5
# 8              7            2
# 9              7            5
# 10             2            1
# 11             1            4
# 12             7            2
# 13             7            4
# 14             7            4
# 15             7            4
# 16             2            1
# 17             2            4
# 18        #NULL!            4
# 19             7            4
# 20             7            4
# 21             2            4
# 22             7            2
# 23             2            3
# 24             7            3
# 25             5            2
# 26             7           99
# 27             2            2
# 28             2       #NULL!
# 29             7            4
# ...

# %%
SNA_ZA_df= SSBOS_19_PPSN[['SNA','SNB', 'SNC', 'SND', 'SNE', 'SNF', 'SNG', 'SNH', 'SNI', 'SNJ', 'SNK', 'SNL', 'SNM', 'SNN', 'SNO', 'SNP', 'SNZZA', 'SNQ', 'SNR', 'SNS', 'SNT', 'SNU', 'SNV', 'SNW', 'SNX', 'SNY', 'SNZ', 'SNZZ', 'SNZZZ']]
SNA_ZA_df
SNA_ZA_df_index =SNA_ZA_df.reset_index()
SNA_ZA_df_index
SNA_ZA_df_counts=SNA_ZA_df_index.sort_values(by = ['SNA','SNB', 'SNC', 'SND', 'SNE', 'SNF', 'SNG', 'SNH', 'SNI', 'SNJ', 'SNK', 'SNL', 'SNM', 'SNN', 'SNO', 'SNP', 'SNZZA', 'SNQ', 'SNR', 'SNS', 'SNT', 'SNU', 'SNV', 'SNW', 'SNX', 'SNY', 'SNZ', 'SNZZ', 'SNZZZ'])
SNA_ZA_df_counts
#Reset index and got column counts
# Out:
#      index                                                SNA     SNB     SNC  \
# 119    119  Offer my support.\nTell them to get help from ...       1       0
# 80      80  Offer my support.\nTell them to talk to a pare...       1       0
# 152    152  Offer my support.\nTell them to talk to a teac...       1       1
# 18      18  Offer my support.\nTell them to talk to a teac...       1       1
# 17      17  Offer my support.\nTell them to talk to a teac...       1       1
# 32      32  Offer my support.\nTell them to talk to a teac...       1       1
# 122    122  Offer my support.\nTell them to talk to a teac...       1       1
# 155    155  Offer my support.\nTell them to talk to a teac...       1       1
# 39      39  Offer my support.\nTell them to talk to a teac...       1       1
# 117    117  Offer my support.\nTell them to talk to a teac...       1       1
# 150    150                                                NaN  #NULL!  #NULL!
# ...

# %%
SSBOS_19_PPSN['SNB'].value_counts()
# Out:
# SNB
# #NULL!    168
# 1          10
# Name: count, dtype: int64

# %%
RI_SN= SSBOS_19_PPSN.groupby(['SNF' = 0,1 ]).count()
RI_SN
#tried to call sspecific values for 'SNF'
# Out:
#   Cell In[13], line 1
#     RI_SN= SSBOS_19_PPSN.groupby(['SNF' = 0,1 ]).count()
#                                   ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
sns.scatterplot(data = SSBOS_19_PPSN , x = 'IGIStandards', y = 'SNR', hue = 'RGIStandards', size = 'IGIStandards', sizes =(20, 200), palette = 'coolwarm')
plt.xlabel("Standard")
plt.ylabel("Eth")
plt.title("Relationship between Standards, Eth and Other")

plt.show

#tried various plots
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
